# %% [markdown]
# # Mudanças de técnicos entre clubes (2018–2025)
# Gera transições de técnicos.

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), '..'))

import pandas as pd
sys.path.append("tecnicos/src_tecnicos")
from src_tecnicos.gerar_clubes_csv import construir_mudancas

df = construir_mudancas("dados/tecnicos.csv", 2018, 2025)
df.to_csv("dados/mudancas_tecnicos_2018_2025.csv", index=False, encoding="utf-8")
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 7
#       5 import pandas as pd
#       6 sys.path.append("tecnicos/src_tecnicos")
# ----> 7 from src_tecnicos.gerar_clubes_csv import construir_mudancas
#       9 df = construir_mudancas("dados/tecnicos.csv", 2018, 2025)
#      10 df.to_csv("dados/mudancas_tecnicos_2018_2025.csv", index=False, encoding="utf-8")
#
# ImportError: cannot import name 'construir_mudancas' from 'src_tecnicos.gerar_clubes_csv' (c:\Users\User\fut_tecnicos\EstudoTecnicosFutebolBrasileiro\dados\tecnicos\src_tecnicos\gerar_clubes_csv.py)
