# %% [markdown]
# # Gerar `clubes.csv` consolidando Série A + B (2018–2025)
# Execute após rodar os notebooks da CBF.

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', '..'))

from src_tecnicos.gerar_clubes_csv import construir_clubes_csv
construir_clubes_csv()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Arquivos dos times não encontrados. Rode os notebooks de clubes (A e B) primeiro.
# c:\Users\User\.pyenv\pyenv-win\versions\3.12.3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
